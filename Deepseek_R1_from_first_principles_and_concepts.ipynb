# %% [markdown]
# <a href="https://colab.research.google.com/github/dhnanjay/HuggingFace/blob/main/Deepseek_R1_from_first_principles_and_concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import locale

def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# !pip install geoopt
# Out:
# Requirement already satisfied: geoopt in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from geoopt) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from geoopt) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from geoopt) (1.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->geoopt) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->geoopt) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->geoopt) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->geoopt) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->geoopt) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->geoopt) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.9.0->geoopt) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.0->geoopt) (3.0.2)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from geoopt import PoincareBall
from geoopt.optim import RiemannianAdam

#model specs
class HyperbolicRLModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(HyperbolicRLModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)~
        self.manifold = PoincareBall(c=1.0)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.manifold.expmap0(x)  # Map to hyperbolic space
        x = self.fc2(self.manifold.logmap0(x))  # Back to Euclidean space
        return x
class CompactRLModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(CompactRLModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# reward function
def compute_accuracy_reward(output, target):
    """Reward based on cosine similarity between output and target embeddings."""
    cos_sim = F.cosine_similarity(output, target, dim=-1)
    return cos_sim.mean().item()

def compute_format_reward(response, required_format):
    """Reward for adhering to the required format."""
    return 1.0 if required_format in response else -1.0

def compute_combined_reward(output, target, response, required_format):
    """Combine accuracy and format rewards."""
    accuracy_reward = compute_accuracy_reward(output, target)
    format_reward = compute_format_reward(response, required_format)
    return accuracy_reward + format_reward

#train function
def train_with_rl(model, optimizer, dataset, input_dim, output_dim, epochs=5, max_seq_len=50):
    """ reinforcement learning."""
    history = []

    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}/{epochs}")
        for sample in dataset:
            prompt = sample["Prompt"]
            target_text = sample["Target"]

            # Generate random embeddings for input and target (replace with actual embeddings in production)
            input_embedding = torch.rand((1, max_seq_len, input_dim)).to(device)
            target_embedding = torch.rand((1, max_seq_len, output_dim)).to(device)

            optimizer.zero_grad()

            # Forward pass
            output_embedding = model(input_embedding)

            # replace with actual decoder this is a dummy
            model_response = "<think> response </think>"

            # Compute rewards
            required_format = "<think>"
            combined_reward = compute_combined_reward(
                output_embedding, target_embedding, model_response, required_format
            )

            # Loss = negative reward (to maximize reward)
            loss = -torch.tensor(combined_reward, requires_grad=True).to(device)

            loss.backward()
            optimizer.step()

            history.append({
                "epoch": epoch + 1,
                "prompt": prompt,
                "reward": combined_reward,
                "loss": loss.item(),
                "response": model_response
            })

            print(f"Prompt: {prompt[:30]}... | Response: {model_response} | Combined Reward: {combined_reward:.4f} | Loss: {loss.item():.4f}")

    return history

# %%
#Distill function
def distill_model(teacher_model, student_model, dataset, optimizer, input_dim, epochs=5, max_seq_len=50):
    """Distill knowledge from the teacher model to the smaller student model."""
    for epoch in range(epochs):
        print(f"Distillation Epoch {epoch + 1}/{epochs}")
        for sample in dataset:
            prompt = sample["Prompt"]

            # Generate random embeddings for input (replace with actual embeddings in production)
            input_embedding = torch.rand((1, max_seq_len, input_dim)).to(device)

            # Teacher model output
            with torch.no_grad():
                teacher_output = teacher_model(input_embedding)

            # Student model output
            student_output = student_model(input_embedding)

            # Loss = Mean Squared Error between teacher and student outputs
            loss = F.mse_loss(student_output, teacher_output)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            print(f"Prompt: {prompt[:30]}... | Distillation Loss: {loss.item():.4f}")

# %%
#  main
if __name__ == "__main__":
    # ---------------------------
    # 1) Device Setup
    # ---------------------------
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # ---------------------------
    # 2) Model and Optimizer Setup
    # ---------------------------
    input_dim = 128  # Example input dimension
    hidden_dim = 256  # Hidden layer dimension
    output_dim = 128  # Output dimension matches input for reconstruction

    model = HyperbolicRLModel(input_dim, hidden_dim, output_dim).to(device)
    optimizer = RiemannianAdam(model.parameters(), lr=1e-4)

  # ---------------------------
    # Dummy data
    # ---------------------------
    dataset = [
        {"Prompt": "If you have 3 apples and you take away 2, how many do you have?", "Target": "2 apples."},
        {"Prompt": "If a train travels 60 miles per hour for 3 hours, how far does it go?", "Target": "180 miles."},
        {"Prompt": "If a store sells a dozen eggs for $3, how much do 2 dozen eggs cost?", "Target": "$6."},
        {"Prompt": "What is the next number in the sequence: 2, 4, 8, 16?", "Target": "32."},
        {"Prompt": "If a rectangle has a length of 5 units and a width of 3 units, what is its area?", "Target": "15 square units."},
        {"Prompt": "If you flip a fair coin 3 times, what is the probability of getting exactly 2 heads?", "Target": "3/8."},
        {"Prompt": "A car decreases its speed from 100 km/h to 50 km/h in 5 seconds. What is the acceleration?", "Target": "-10 km/h/s."},
        {"Prompt": "If 5 workers can complete a job in 10 days, how long will it take 10 workers to complete the same job?", "Target": "5 days."},
        {"Prompt": "If the sum of two numbers is 15 and their product is 56, what are the numbers?", "Target": "7 and 8."},
        {"Prompt": "What is the angle between the hour and minute hands of a clock at 3:15?", "Target": "7.5 degrees."}
    ]


    #Training

    history = train_with_rl(
        model=model,
        optimizer=optimizer,
        dataset=dataset,
        input_dim=input_dim,
        output_dim=output_dim,
        epochs=10,
        max_seq_len=50
    )

    print("Training complete.")


    #  Distillation

    smaller_model = CompactRLModel(input_dim, hidden_dim // 2, output_dim).to(device)
    distill_optimizer = torch.optim.Adam(smaller_model.parameters(), lr=1e-4)

    distill_model(
        teacher_model=model,
        student_model=smaller_model,
        dataset=dataset,
        optimizer=distill_optimizer,
        input_dim=input_dim,
        epochs=10,
        max_seq_len=50
    )

    print("Distillation complete.")
# Out:
# Epoch 1/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0254 | Loss: -1.0254
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0266 | Loss: -1.0266
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0142 | Loss: -1.0142
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0146 | Loss: -1.0146
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0316 | Loss: -1.0316
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0317 | Loss: -1.0317
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0173 | Loss: -1.0173
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0297 | Loss: -1.0297
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0259 | Loss: -1.0259
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0400 | Loss: -1.0400
# Epoch 2/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0194 | Loss: -1.0194
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0300 | Loss: -1.0300
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0299 | Loss: -1.0299
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0260 | Loss: -1.0260
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0285 | Loss: -1.0285
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0180 | Loss: -1.0180
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0252 | Loss: -1.0252
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0288 | Loss: -1.0288
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0243 | Loss: -1.0243
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0382 | Loss: -1.0382
# Epoch 3/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0168 | Loss: -1.0168
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0352 | Loss: -1.0352
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0345 | Loss: -1.0345
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0195 | Loss: -1.0195
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0327 | Loss: -1.0327
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0041 | Loss: -1.0041
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0084 | Loss: -1.0084
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0268 | Loss: -1.0268
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0338 | Loss: -1.0338
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0303 | Loss: -1.0303
# Epoch 4/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0280 | Loss: -1.0280
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0193 | Loss: -1.0193
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0153 | Loss: -1.0153
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0181 | Loss: -1.0181
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0259 | Loss: -1.0259
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0265 | Loss: -1.0265
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0304 | Loss: -1.0304
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0157 | Loss: -1.0157
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0296 | Loss: -1.0296
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0300 | Loss: -1.0300
# Epoch 5/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0341 | Loss: -1.0341
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0257 | Loss: -1.0257
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0162 | Loss: -1.0162
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0344 | Loss: -1.0344
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0146 | Loss: -1.0146
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0217 | Loss: -1.0217
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0239 | Loss: -1.0239
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0360 | Loss: -1.0360
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0143 | Loss: -1.0143
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0260 | Loss: -1.0260
# Epoch 6/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0351 | Loss: -1.0351
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0337 | Loss: -1.0337
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0211 | Loss: -1.0211
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0302 | Loss: -1.0302
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0172 | Loss: -1.0172
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0244 | Loss: -1.0244
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0293 | Loss: -1.0293
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0211 | Loss: -1.0211
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0106 | Loss: -1.0106
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0307 | Loss: -1.0307
# Epoch 7/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0165 | Loss: -1.0165
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0226 | Loss: -1.0226
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0372 | Loss: -1.0372
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0218 | Loss: -1.0218
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0167 | Loss: -1.0167
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0361 | Loss: -1.0361
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0254 | Loss: -1.0254
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0191 | Loss: -1.0191
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0315 | Loss: -1.0315
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0245 | Loss: -1.0245
# Epoch 8/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0261 | Loss: -1.0261
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0223 | Loss: -1.0223
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0325 | Loss: -1.0325
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0270 | Loss: -1.0270
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0290 | Loss: -1.0290
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0185 | Loss: -1.0185
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0419 | Loss: -1.0419
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0345 | Loss: -1.0345
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0264 | Loss: -1.0264
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0253 | Loss: -1.0253
# Epoch 9/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0345 | Loss: -1.0345
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0163 | Loss: -1.0163
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0287 | Loss: -1.0287
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0266 | Loss: -1.0266
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0386 | Loss: -1.0386
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0211 | Loss: -1.0211
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0272 | Loss: -1.0272
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0415 | Loss: -1.0415
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0368 | Loss: -1.0368
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0279 | Loss: -1.0279
# Epoch 10/10
# Prompt: If you have 3 apples and you t... | Response: <think> response </think> | Combined Reward: 1.0180 | Loss: -1.0180
# Prompt: If a train travels 60 miles pe... | Response: <think> response </think> | Combined Reward: 1.0330 | Loss: -1.0330
# Prompt: If a store sells a dozen eggs ... | Response: <think> response </think> | Combined Reward: 1.0290 | Loss: -1.0290
# Prompt: What is the next number in the... | Response: <think> response </think> | Combined Reward: 1.0314 | Loss: -1.0314
# Prompt: If a rectangle has a length of... | Response: <think> response </think> | Combined Reward: 1.0295 | Loss: -1.0295
# Prompt: If you flip a fair coin 3 time... | Response: <think> response </think> | Combined Reward: 1.0260 | Loss: -1.0260
# Prompt: A car decreases its speed from... | Response: <think> response </think> | Combined Reward: 1.0162 | Loss: -1.0162
# Prompt: If 5 workers can complete a jo... | Response: <think> response </think> | Combined Reward: 1.0215 | Loss: -1.0215
# Prompt: If the sum of two numbers is 1... | Response: <think> response </think> | Combined Reward: 1.0054 | Loss: -1.0054
# Prompt: What is the angle between the ... | Response: <think> response </think> | Combined Reward: 1.0288 | Loss: -1.0288
# Training complete.
# Distillation Epoch 1/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0399
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0386
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0373
# Prompt: What is the next number in the... | Distillation Loss: 0.0363
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0355
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0336
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0337
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0320
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0312
# Prompt: What is the angle between the ... | Distillation Loss: 0.0301
# Distillation Epoch 2/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0294
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0290
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0281
# Prompt: What is the next number in the... | Distillation Loss: 0.0269
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0261
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0261
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0250
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0241
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0233
# Prompt: What is the angle between the ... | Distillation Loss: 0.0233
# Distillation Epoch 3/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0224
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0222
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0213
# Prompt: What is the next number in the... | Distillation Loss: 0.0211
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0202
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0198
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0192
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0193
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0189
# Prompt: What is the angle between the ... | Distillation Loss: 0.0184
# Distillation Epoch 4/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0177
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0172
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0173
# Prompt: What is the next number in the... | Distillation Loss: 0.0164
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0163
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0159
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0157
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0151
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0149
# Prompt: What is the angle between the ... | Distillation Loss: 0.0146
# Distillation Epoch 5/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0141
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0144
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0138
# Prompt: What is the next number in the... | Distillation Loss: 0.0136
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0135
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0126
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0130
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0126
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0123
# Prompt: What is the angle between the ... | Distillation Loss: 0.0123
# Distillation Epoch 6/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0118
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0115
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0113
# Prompt: What is the next number in the... | Distillation Loss: 0.0110
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0109
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0108
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0105
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0103
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0101
# Prompt: What is the angle between the ... | Distillation Loss: 0.0101
# Distillation Epoch 7/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0098
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0095
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0093
# Prompt: What is the next number in the... | Distillation Loss: 0.0092
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0093
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0088
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0089
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0089
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0084
# Prompt: What is the angle between the ... | Distillation Loss: 0.0087
# Distillation Epoch 8/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0085
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0084
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0081
# Prompt: What is the next number in the... | Distillation Loss: 0.0081
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0083
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0080
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0076
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0077
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0075
# Prompt: What is the angle between the ... | Distillation Loss: 0.0077
# Distillation Epoch 9/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0075
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0074
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0072
# Prompt: What is the next number in the... | Distillation Loss: 0.0072
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0072
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0070
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0070
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0069
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0069
# Prompt: What is the angle between the ... | Distillation Loss: 0.0068
# Distillation Epoch 10/10
# Prompt: If you have 3 apples and you t... | Distillation Loss: 0.0068
# Prompt: If a train travels 60 miles pe... | Distillation Loss: 0.0068
# Prompt: If a store sells a dozen eggs ... | Distillation Loss: 0.0068
# Prompt: What is the next number in the... | Distillation Loss: 0.0066
# Prompt: If a rectangle has a length of... | Distillation Loss: 0.0068
# Prompt: If you flip a fair coin 3 time... | Distillation Loss: 0.0068
# Prompt: A car decreases its speed from... | Distillation Loss: 0.0065
# Prompt: If 5 workers can complete a jo... | Distillation Loss: 0.0066
# Prompt: If the sum of two numbers is 1... | Distillation Loss: 0.0067
# Prompt: What is the angle between the ... | Distillation Loss: 0.0063
# Distillation complete.
